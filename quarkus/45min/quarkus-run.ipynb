# %%
import csv
import json
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# # Quarkus Blocking

# %%
# path params
json_path = './qbj-ilo.json'
csv_file1 = "./output/qbj.csv"
plot_image_file = "./output/qbj-final.png"

with open(json_path, 'r') as file1:
    loaded_data = json.load(file1)

# Extract Time and Average
data1 = loaded_data["PowerDetail"]
time_values1 = [datetime.fromisoformat(entry["Time"].replace("Z", "+00:00")) for entry in data1]
average_values1 = [entry["Average"] for entry in data1]


with open(csv_file1, mode='w', newline='') as file1:
    writer1 = csv.writer(file1)
    writer1.writerow(["Time", "Average"])  # Write header row
    writer1.writerows(zip(time_values1, average_values1))  # Write data rows

print(f'Data from the JSON file has been written to "{csv_file1}".')

# Create two subplots sharing the same X-axis
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot the PowerDetail data on the left Y-axis
ax1.plot(time_values1, average_values1, marker='.', linestyle='-', label="Power Average", color='blue')
ax1.set_xlabel('Time')
ax1.set_ylabel('Power Average', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_ylim(140, 210)

# Title and legend
plt.title('Quarkus Blocking JAR 45 Min')
plt.legend(loc='upper left')

# Format x-axis labels as dates
plt.xticks(rotation=45)

plt.savefig(plot_image_file)

# Show the plot
plt.tight_layout()
plt.show()

print(f'Combined plot has been saved as "{plot_image_file}".')
# Out:
# Data from the JSON file has been written to "./output/qbj.csv".
# Combined plot has been saved as "./output/qbj-final.png".

# %% [markdown]
# # Quarkus Virtual Threads

# %%
# path params
json_path = './qbvj-ilo.json'
csv_file1 = "./output/qbvj.csv"
plot_image_file = "./output/qbvj-final.png"

with open(json_path, 'r') as file1:
    loaded_data = json.load(file1)

# Extract Time and Average
data1 = loaded_data["PowerDetail"]
time_values1 = [datetime.fromisoformat(entry["Time"].replace("Z", "+00:00")) for entry in data1]
average_values1 = [entry["Average"] for entry in data1]


with open(csv_file1, mode='w', newline='') as file1:
    writer1 = csv.writer(file1)
    writer1.writerow(["Time", "Average"])  # Write header row
    writer1.writerows(zip(time_values1, average_values1))  # Write data rows

print(f'Data from the JSON file has been written to "{csv_file1}".')

# Create two subplots sharing the same X-axis
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot the PowerDetail data on the left Y-axis
ax1.plot(time_values1, average_values1, marker='.', linestyle='-', label="Power Average", color='blue')
ax1.set_xlabel('Time')
ax1.set_ylabel('Power Average', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_ylim(140, 210)

# Title and legend
plt.title('Quarkus Virtual Threads JAR 45 Min')
plt.legend(loc='upper left')

# Format x-axis labels as dates
plt.xticks(rotation=45)

plt.savefig(plot_image_file)

# Show the plot
plt.tight_layout()
plt.show()

print(f'Combined plot has been saved as "{plot_image_file}".')
# Out:
# Data from the JSON file has been written to "./output/qbvj.csv".
# Combined plot has been saved as "./output/qbvj-final.png".

# %% [markdown]
# # Quarkus Non-Blocking Jar

# %%
# path params
json_path = './qrj-ilo.json'
csv_file1 = "./output/qrj.csv"
plot_image_file = "./output/qrj-final.png"

with open(json_path, 'r') as file1:
    loaded_data = json.load(file1)

# Extract Time and Average
data1 = loaded_data["PowerDetail"]
time_values1 = [datetime.fromisoformat(entry["Time"].replace("Z", "+00:00")) for entry in data1]
average_values1 = [entry["Average"] for entry in data1]


with open(csv_file1, mode='w', newline='') as file1:
    writer1 = csv.writer(file1)
    writer1.writerow(["Time", "Average"])  # Write header row
    writer1.writerows(zip(time_values1, average_values1))  # Write data rows

print(f'Data from the JSON file has been written to "{csv_file1}".')

# Create two subplots sharing the same X-axis
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot the PowerDetail data on the left Y-axis
ax1.plot(time_values1, average_values1, marker='.', linestyle='-', label="Power Average", color='blue')
ax1.set_xlabel('Time')
ax1.set_ylabel('Power Average', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_ylim(140, 210)

# Title and legend
plt.title('Quarkus Non-Blocking JAR 45 Min')
plt.legend(loc='upper left')

# Format x-axis labels as dates
plt.xticks(rotation=45)

plt.savefig(plot_image_file)

# Show the plot
plt.tight_layout()
plt.show()

print(f'Combined plot has been saved as "{plot_image_file}".')
# Out:
# Data from the JSON file has been written to "./output/qrj.csv".
# Combined plot has been saved as "./output/qrj-final.png".

# %%
# quarkus-non-blocking-jar-ilo.json\


# path params
json_path = './quarkus-non-blocking-jar-ilo.json'
csv_file1 = "./output/quarkus-non-blocking-jar-new.csv"
plot_image_file = "./output/quarkus-non-blocking-jar-new.png"

with open(json_path, 'r') as file1:
    loaded_data = json.load(file1)

# Extract Time and Average
data1 = loaded_data["PowerDetail"]
time_values1 = [datetime.fromisoformat(entry["Time"].replace("Z", "+00:00")) for entry in data1]
average_values1 = [entry["Average"] for entry in data1]


with open(csv_file1, mode='w', newline='') as file1:
    writer1 = csv.writer(file1)
    writer1.writerow(["Time", "Average"])  # Write header row
    writer1.writerows(zip(time_values1, average_values1))  # Write data rows

print(f'Data from the JSON file has been written to "{csv_file1}".')

# Create two subplots sharing the same X-axis
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot the PowerDetail data on the left Y-axis
ax1.plot(time_values1, average_values1, marker='.', linestyle='-', label="Power Average", color='blue')
ax1.set_xlabel('Time')
ax1.set_ylabel('Power Average', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_ylim(140, 210)

# Title and legend
plt.title('Quarkus Non-Blocking JAR 45 Min')
plt.legend(loc='upper left')

# Format x-axis labels as dates
plt.xticks(rotation=45)

plt.savefig(plot_image_file)

# Show the plot
plt.tight_layout()
plt.show()

print(f'Combined plot has been saved as "{plot_image_file}".')
# Out:
# Data from the JSON file has been written to "./output/quarkus-non-blocking-jar-new.csv".
# Combined plot has been saved as "./output/quarkus-non-blocking-jar-new.png".

# %% [markdown]
# # Quarkus GraalVM Blocking

# %%
# path params
json_path = './qbg-ilo.json'
csv_file1 = "./output/qbg.csv"
plot_image_file = "./output/qbg-final.png"

with open(json_path, 'r') as file1:
    loaded_data = json.load(file1)

# Extract Time and Average
data1 = loaded_data["PowerDetail"]
time_values1 = [datetime.fromisoformat(entry["Time"].replace("Z", "+00:00")) for entry in data1]
average_values1 = [entry["Average"] for entry in data1]


with open(csv_file1, mode='w', newline='') as file1:
    writer1 = csv.writer(file1)
    writer1.writerow(["Time", "Average"])  # Write header row
    writer1.writerows(zip(time_values1, average_values1))  # Write data rows

print(f'Data from the JSON file has been written to "{csv_file1}".')

# Create two subplots sharing the same X-axis
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot the PowerDetail data on the left Y-axis
ax1.plot(time_values1, average_values1, marker='.', linestyle='-', label="Power Average", color='blue')
ax1.set_xlabel('Time')
ax1.set_ylabel('Power Average', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_ylim(140, 210)

# Title and legend
plt.title('Quarkus Blocking Native Executable 45 Min')
plt.legend(loc='upper left')

# Format x-axis labels as dates
plt.xticks(rotation=45)

plt.savefig(plot_image_file)

# Show the plot
plt.tight_layout()
plt.show()

print(f'Combined plot has been saved as "{plot_image_file}".')
# Out:
# Data from the JSON file has been written to "./output/qbg.csv".
# Combined plot has been saved as "./output/qbg-final.png".

# %% [markdown]
# # Quarkus GraalVM Non-Blocking

# %%
# path params
json_path = './qrg-ilo.json'
csv_file1 = "./output/qrg.csv"
plot_image_file = "./output/qrg-final.png"

with open(json_path, 'r') as file1:
    loaded_data = json.load(file1)

# Extract Time and Average
data1 = loaded_data["PowerDetail"]
time_values1 = [datetime.fromisoformat(entry["Time"].replace("Z", "+00:00")) for entry in data1]
average_values1 = [entry["Average"] for entry in data1]


with open(csv_file1, mode='w', newline='') as file1:
    writer1 = csv.writer(file1)
    writer1.writerow(["Time", "Average"])  # Write header row
    writer1.writerows(zip(time_values1, average_values1))  # Write data rows

print(f'Data from the JSON file has been written to "{csv_file1}".')

# Create two subplots sharing the same X-axis
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot the PowerDetail data on the left Y-axis
ax1.plot(time_values1, average_values1, marker='.', linestyle='-', label="Power Average", color='blue')
ax1.set_xlabel('Time')
ax1.set_ylabel('Power Average', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_ylim(140, 210)

# Title and legend
plt.title('Quarkus Non-Blocking Native Executable 45 Min')
plt.legend(loc='upper left')

# Format x-axis labels as dates
plt.xticks(rotation=45)

plt.savefig(plot_image_file)

# Show the plot
plt.tight_layout()
plt.show()

print(f'Combined plot has been saved as "{plot_image_file}".')
# Out:
# Data from the JSON file has been written to "./output/qrg.csv".
# Combined plot has been saved as "./output/qrg-final.png".
