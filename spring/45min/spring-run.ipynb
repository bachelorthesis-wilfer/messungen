# %%
import csv
import json
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# # Spring Blocking

# %%
# path params
json_path = './sbj-ilo.json'
csv_file1 = "./output/sbj.csv"
plot_image_file = "./output/sbj-final.png"

with open(json_path, 'r') as file1:
    loaded_data = json.load(file1)

# Extract Time and Average
data1 = loaded_data["PowerDetail"]
time_values1 = [datetime.fromisoformat(entry["Time"].replace("Z", "+00:00")) for entry in data1]
average_values1 = [entry["Average"] for entry in data1]


with open(csv_file1, mode='w', newline='') as file1:
    writer1 = csv.writer(file1)
    writer1.writerow(["Time", "Average"])  # Write header row
    writer1.writerows(zip(time_values1, average_values1))  # Write data rows

print(f'Data from the JSON file has been written to "{csv_file1}".')

# Create two subplots sharing the same X-axis
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot the PowerDetail data on the left Y-axis
ax1.plot(time_values1, average_values1, marker='.', linestyle='-', label="Power Average", color='blue')
ax1.set_xlabel('Time')
ax1.set_ylabel('Power Average', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_ylim(140, 210)

# Title and legend
plt.title('Spring Blocking JAR 45 Min')
plt.legend(loc='upper left')

# Format x-axis labels as dates
plt.xticks(rotation=45)

plt.savefig(plot_image_file)

# Show the plot
plt.tight_layout()
plt.show()

print(f'Combined plot has been saved as "{plot_image_file}".')
# Out:
# Data from the JSON file has been written to "./output/sbj.csv".
# Combined plot has been saved as "./output/sbj-final.png".

# %% [markdown]
# # Spring Virtual Threads

# %%
# path params
json_path = './sbvj-ilo.json'
csv_file1 = "./output/sbvj.csv"
plot_image_file = "./output/sbvj-final.png"

with open(json_path, 'r') as file1:
    loaded_data = json.load(file1)

# Extract Time and Average
data1 = loaded_data["PowerDetail"]
time_values1 = [datetime.fromisoformat(entry["Time"].replace("Z", "+00:00")) for entry in data1]
average_values1 = [entry["Average"] for entry in data1]


with open(csv_file1, mode='w', newline='') as file1:
    writer1 = csv.writer(file1)
    writer1.writerow(["Time", "Average"])  # Write header row
    writer1.writerows(zip(time_values1, average_values1))  # Write data rows

print(f'Data from the JSON file has been written to "{csv_file1}".')

# Create two subplots sharing the same X-axis
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot the PowerDetail data on the left Y-axis
ax1.plot(time_values1, average_values1, marker='.', linestyle='-', label="Power Average", color='blue')
ax1.set_xlabel('Time')
ax1.set_ylabel('Power Average', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_ylim(140, 210)

# Title and legend
plt.title('Spring Virtual Threads JAR 45 Min')
plt.legend(loc='upper left')

# Format x-axis labels as dates
plt.xticks(rotation=45)

plt.savefig(plot_image_file)

# Show the plot
plt.tight_layout()
plt.show()

print(f'Combined plot has been saved as "{plot_image_file}".')
# Out:
# Data from the JSON file has been written to "./output/sbvj.csv".
# Combined plot has been saved as "./output/sbvj-final.png".

# %% [markdown]
# # Spring Non-Blocking

# %%
# path params
json_path = './srj-ilo.json'
csv_file1 = "./output/srj.csv"
plot_image_file = "./output/srj-final.png"

with open(json_path, 'r') as file1:
    loaded_data = json.load(file1)

# Extract Time and Average
data1 = loaded_data["PowerDetail"]
time_values1 = [datetime.fromisoformat(entry["Time"].replace("Z", "+00:00")) for entry in data1]
average_values1 = [entry["Average"] for entry in data1]


with open(csv_file1, mode='w', newline='') as file1:
    writer1 = csv.writer(file1)
    writer1.writerow(["Time", "Average"])  # Write header row
    writer1.writerows(zip(time_values1, average_values1))  # Write data rows

print(f'Data from the JSON file has been written to "{csv_file1}".')

# Create two subplots sharing the same X-axis
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot the PowerDetail data on the left Y-axis
ax1.plot(time_values1, average_values1, marker='.', linestyle='-', label="Power Average", color='blue')
ax1.set_xlabel('Time')
ax1.set_ylabel('Power Average', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_ylim(140, 210)

# Title and legend
plt.title('Spring Non-Blocking JAR 45 Min')
plt.legend(loc='upper left')

# Format x-axis labels as dates
plt.xticks(rotation=45)

plt.savefig(plot_image_file)

# Show the plot
plt.tight_layout()
plt.show()

print(f'Combined plot has been saved as "{plot_image_file}".')
# Out:
# Data from the JSON file has been written to "./output/srj.csv".
# Combined plot has been saved as "./output/srj-final.png".

# %% [markdown]
# # Spring GraalVM Blocking

# %%
# path params
json_path = './sbg-ilo.json'
csv_file1 = "./output/sbg.csv"
plot_image_file = "./output/sbg-final.png"

with open(json_path, 'r') as file1:
    loaded_data = json.load(file1)

# Extract Time and Average
data1 = loaded_data["PowerDetail"]
time_values1 = [datetime.fromisoformat(entry["Time"].replace("Z", "+00:00")) for entry in data1]
average_values1 = [entry["Average"] for entry in data1]


with open(csv_file1, mode='w', newline='') as file1:
    writer1 = csv.writer(file1)
    writer1.writerow(["Time", "Average"])  # Write header row
    writer1.writerows(zip(time_values1, average_values1))  # Write data rows

print(f'Data from the JSON file has been written to "{csv_file1}".')

# Create two subplots sharing the same X-axis
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot the PowerDetail data on the left Y-axis
ax1.plot(time_values1, average_values1, marker='.', linestyle='-', label="Power Average", color='blue')
ax1.set_xlabel('Time')
ax1.set_ylabel('Power Average', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_ylim(140, 210)

# Title and legend
plt.title('Spring Blocking Native Executable 45 Min')
plt.legend(loc='upper left')

# Format x-axis labels as dates
plt.xticks(rotation=45)

plt.savefig(plot_image_file)

# Show the plot
plt.tight_layout()
plt.show()

print(f'Combined plot has been saved as "{plot_image_file}".')
# Out:
# Data from the JSON file has been written to "./output/sbg.csv".
# Combined plot has been saved as "./output/sbg-final.png".

# %% [markdown]
# # Spring GraalVM Non-Blocking

# %%
# path params
json_path = './srg-ilo.json'
csv_file1 = "./output/srg.csv"
plot_image_file = "./output/srg-final.png"

with open(json_path, 'r') as file1:
    loaded_data = json.load(file1)

# Extract Time and Average
data1 = loaded_data["PowerDetail"]
time_values1 = [datetime.fromisoformat(entry["Time"].replace("Z", "+00:00")) for entry in data1]
average_values1 = [entry["Average"] for entry in data1]


with open(csv_file1, mode='w', newline='') as file1:
    writer1 = csv.writer(file1)
    writer1.writerow(["Time", "Average"])  # Write header row
    writer1.writerows(zip(time_values1, average_values1))  # Write data rows

print(f'Data from the JSON file has been written to "{csv_file1}".')

# Create two subplots sharing the same X-axis
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot the PowerDetail data on the left Y-axis
ax1.plot(time_values1, average_values1, marker='.', linestyle='-', label="Power Average", color='blue')
ax1.set_xlabel('Time')
ax1.set_ylabel('Power Average', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_ylim(140, 210)

# Title and legend
plt.title('Spring Non-Blocking Native Executable 45 Min')
plt.legend(loc='upper left')

# Format x-axis labels as dates
plt.xticks(rotation=45)

plt.savefig(plot_image_file)

# Show the plot
plt.tight_layout()
plt.show()

print(f'Combined plot has been saved as "{plot_image_file}".')
# Out:
# Data from the JSON file has been written to "./output/srg.csv".
# Combined plot has been saved as "./output/srg-final.png".
