# %%
import csv
import json
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# # Spring Blocking

# %%
# path params
json_path = './sbj-ilo.json'
csv_file1 = "./output/10min-spring-blocking-jar.csv"
plot_image_file = "./output/10min-spring-blocking-jar.png"

with open(json_path, 'r') as file1:
    loaded_data = json.load(file1)

# Extract Time and Average
data1 = loaded_data["PowerDetail"]
time_values1 = [datetime.fromisoformat(entry["Time"].replace("Z", "+00:00")) for entry in data1]
average_values1 = [entry["Average"] for entry in data1]


with open(csv_file1, mode='w', newline='') as file1:
    writer1 = csv.writer(file1)
    writer1.writerow(["Time", "Average"])  # Write header row
    writer1.writerows(zip(time_values1, average_values1))  # Write data rows

print(f'Data from the JSON file has been written to "{csv_file1}".')

# Create two subplots sharing the same X-axis
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot the PowerDetail data on the left Y-axis
ax1.plot(time_values1, average_values1, marker='.', linestyle='-', label="Power Average", color='blue')
ax1.set_xlabel('Time')
ax1.set_ylabel('Power Average', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_ylim(140, 260)

# Title and legend
plt.title('Spring Blocking Platform JAR 10 Min')
plt.legend(loc='upper right')

# Format x-axis labels as dates
plt.xticks(rotation=45)

plt.savefig(plot_image_file)

# Show the plot
plt.tight_layout()
plt.show()

print(f'Combined plot has been saved as "{plot_image_file}".')
# Out:
# Data from the JSON file has been written to "./output/10min-spring-blocking-jar.csv".
# Combined plot has been saved as "./output/10min-spring-blocking-jar.png".

# %% [markdown]
# # Spring Virtual Threads

# %%
# path params
json_path = './sbvj-ilo.json'
csv_file1 = "./output/10min-spring-blocking-virtual-jar.csv"
plot_image_file = "./output/10min-spring-blocking-virtual-jar.png"

with open(json_path, 'r') as file1:
    loaded_data = json.load(file1)

# Extract Time and Average
data1 = loaded_data["PowerDetail"]
time_values1 = [datetime.fromisoformat(entry["Time"].replace("Z", "+00:00")) for entry in data1]
average_values1 = [entry["Average"] for entry in data1]


with open(csv_file1, mode='w', newline='') as file1:
    writer1 = csv.writer(file1)
    writer1.writerow(["Time", "Average"])  # Write header row
    writer1.writerows(zip(time_values1, average_values1))  # Write data rows

print(f'Data from the JSON file has been written to "{csv_file1}".')

# Create two subplots sharing the same X-axis
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot the PowerDetail data on the left Y-axis
ax1.plot(time_values1, average_values1, marker='.', linestyle='-', label="Power Average", color='blue')
ax1.set_xlabel('Time')
ax1.set_ylabel('Power Average', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_ylim(140, 260)

# Title and legend
plt.title('Spring Blocking Virtual JAR 10 Min')
plt.legend(loc='upper right')

# Format x-axis labels as dates
plt.xticks(rotation=45)

plt.savefig(plot_image_file)

# Show the plot
plt.tight_layout()
plt.show()

print(f'Combined plot has been saved as "{plot_image_file}".')
# Out:
# Data from the JSON file has been written to "./output/10min-spring-blocking-virtual-jar.csv".
# Combined plot has been saved as "./output/10min-spring-blocking-virtual-jar.png".

# %% [markdown]
# # Spring Non-Blocking

# %%
# path params
json_path = './srj-ilo.json'
csv_file1 = "./output/10min-spring-non-blocking-jar.csv"
plot_image_file = "./output/10min-spring-non-blocking-jar.png"

with open(json_path, 'r') as file1:
    loaded_data = json.load(file1)

# Extract Time and Average
data1 = loaded_data["PowerDetail"]
time_values1 = [datetime.fromisoformat(entry["Time"].replace("Z", "+00:00")) for entry in data1]
average_values1 = [entry["Average"] for entry in data1]


with open(csv_file1, mode='w', newline='') as file1:
    writer1 = csv.writer(file1)
    writer1.writerow(["Time", "Average"])  # Write header row
    writer1.writerows(zip(time_values1, average_values1))  # Write data rows

print(f'Data from the JSON file has been written to "{csv_file1}".')

# Create two subplots sharing the same X-axis
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot the PowerDetail data on the left Y-axis
ax1.plot(time_values1, average_values1, marker='.', linestyle='-', label="Power Average", color='blue')
ax1.set_xlabel('Time')
ax1.set_ylabel('Power Average', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_ylim(140, 260)

# Title and legend
plt.title('Spring Non-Blocking JAR 10 Min')
plt.legend(loc='upper right')

# Format x-axis labels as dates
plt.xticks(rotation=45)

plt.savefig(plot_image_file)

# Show the plot
plt.tight_layout()
plt.show()

print(f'Combined plot has been saved as "{plot_image_file}".')
# Out:
# Data from the JSON file has been written to "./output/10min-spring-non-blocking-jar.csv".
# Combined plot has been saved as "./output/10min-spring-non-blocking-jar.png".

# %% [markdown]
# # Spring GraalVM Blocking

# %%
# path params
json_path = './sbg-ilo.json'
csv_file1 = "./output/10min-spring-blocking-graal.csv"
plot_image_file = "./output/10min-spring-blocking-graal.png"

with open(json_path, 'r') as file1:
    loaded_data = json.load(file1)

# Extract Time and Average
data1 = loaded_data["PowerDetail"]
time_values1 = [datetime.fromisoformat(entry["Time"].replace("Z", "+00:00")) for entry in data1]
average_values1 = [entry["Average"] for entry in data1]


with open(csv_file1, mode='w', newline='') as file1:
    writer1 = csv.writer(file1)
    writer1.writerow(["Time", "Average"])  # Write header row
    writer1.writerows(zip(time_values1, average_values1))  # Write data rows

print(f'Data from the JSON file has been written to "{csv_file1}".')

# Create two subplots sharing the same X-axis
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot the PowerDetail data on the left Y-axis
ax1.plot(time_values1, average_values1, marker='.', linestyle='-', label="Power Average", color='blue')
ax1.set_xlabel('Time')
ax1.set_ylabel('Power Average', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_ylim(140, 260)

# Title and legend
plt.title('Spring Blocking Native Executable 10 Min')
plt.legend(loc='upper right')

# Format x-axis labels as dates
plt.xticks(rotation=45)

plt.savefig(plot_image_file)

# Show the plot
plt.tight_layout()
plt.show()

print(f'Combined plot has been saved as "{plot_image_file}".')
# Out:
# Data from the JSON file has been written to "./output/10min-spring-blocking-graal.csv".
# Combined plot has been saved as "./output/10min-spring-blocking-graal.png".

# %% [markdown]
# # Spring GraalVM Non-Blocking

# %%
# path params
json_path = './srg-ilo.json'
csv_file1 = "./output/10min-spring-non-blocking-graal.csv"
plot_image_file = "./output/10min-spring-non-blocking-graal.png"

with open(json_path, 'r') as file1:
    loaded_data = json.load(file1)

# Extract Time and Average
data1 = loaded_data["PowerDetail"]
time_values1 = [datetime.fromisoformat(entry["Time"].replace("Z", "+00:00")) for entry in data1]
average_values1 = [entry["Average"] for entry in data1]


with open(csv_file1, mode='w', newline='') as file1:
    writer1 = csv.writer(file1)
    writer1.writerow(["Time", "Average"])  # Write header row
    writer1.writerows(zip(time_values1, average_values1))  # Write data rows

print(f'Data from the JSON file has been written to "{csv_file1}".')

# Create two subplots sharing the same X-axis
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot the PowerDetail data on the left Y-axis
ax1.plot(time_values1, average_values1, marker='.', linestyle='-', label="Power Average", color='blue')
ax1.set_xlabel('Time')
ax1.set_ylabel('Power Average', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_ylim(140, 260)

# Title and legend
plt.title('Spring Non-Blocking Native Executable 10 Min')
plt.legend(loc='upper right')

# Format x-axis labels as dates
plt.xticks(rotation=45)

plt.savefig(plot_image_file)

# Show the plot
plt.tight_layout()
plt.show()

print(f'Combined plot has been saved as "{plot_image_file}".')
# Out:
# Data from the JSON file has been written to "./output/10min-spring-non-blocking-graal.csv".
# Combined plot has been saved as "./output/10min-spring-non-blocking-graal.png".

# %%
# From GPT zusammengewurschtelt

import json
import csv
import matplotlib.pyplot as plt
from datetime import datetime

# Define the paths and colors for each dataset
datasets = [
    {"json_path": './sbj-ilo.json', "csv_file": "./output/10min-sbj.csv", "color": "blue", "label": "SBJ"},
    {"json_path": './srg-ilo.json', "csv_file": "./output/10min-srg.csv", "color": "red", "label": "SRG"},
    {"json_path": './srj-ilo.json', "csv_file": "./output/10min-srj.csv", "color": "green", "label": "SRJ"},
    {"json_path": './sbvj-ilo.json', "csv_file": "./output/10min-sbvj.csv", "color": "purple", "label": "SBVJ"},
    {"json_path": './sbg-ilo.json', "csv_file": "./output/10min-sbg.csv", "color": "orange", "label": "SBG"}
]

# Create figure and axis for the combined plot
fig, ax1 = plt.subplots(figsize=(10, 5))

for dataset in datasets:
    json_path = dataset["json_path"]
    csv_file = dataset["csv_file"]
    color = dataset["color"]
    label = dataset["label"]

    # Load JSON data
    with open(json_path, 'r') as file1:
        loaded_data = json.load(file1)

    # Extract Time and Average
    data1 = loaded_data["PowerDetail"]
    time_values1 = [datetime.fromisoformat(entry["Time"].replace("Z", "+00:00")) for entry in data1]
    average_values1 = [entry["Average"] for entry in data1]

    # Write the data to the CSV file
    with open(csv_file, mode='w', newline='') as file1:
        writer1 = csv.writer(file1)
        writer1.writerow(["Time", "Average"])  # Write header row
        writer1.writerows(zip(time_values1, average_values1))  # Write data rows

    print(f'Data from the JSON file has been written to "{csv_file}".')

    # Plot the data
    ax1.plot(time_values1, average_values1, marker='.', linestyle='-', label=label, color=color)

# Customize the plot
ax1.set_xlabel('Time')
ax1.set_ylabel('Power Average')
ax1.tick_params(axis='y')
ax1.set_ylim(140, 260)

# Title and legend
plt.title('Combined Spring 10 Min')
plt.legend(loc='upper right')

# Format x-axis labels as dates
plt.xticks(rotation=45)

# Save the combined plot
plot_image_file = "./output/combined_plot.png"
plt.savefig(plot_image_file)

# Show the plot
plt.tight_layout()
plt.show()

print(f'Combined plot has been saved as "{plot_image_file}".')
# Out:
# Data from the JSON file has been written to "./output/10min-sbj.csv".
# Data from the JSON file has been written to "./output/10min-srg.csv".
# Data from the JSON file has been written to "./output/10min-srj.csv".
# Data from the JSON file has been written to "./output/10min-sbvj.csv".
# Data from the JSON file has been written to "./output/10min-sbg.csv".
# Combined plot has been saved as "./output/combined_plot.png".

# %% [markdown]
# # Mean und Average

# %%
import pandas as pd
csv_files = [
    "./output/10min-sbj.csv",
    "./output/10min-srg.csv",
    "./output/10min-srj.csv",
    "./output/10min-sbvj.csv",
    "./output/10min-sbg.csv"
]


# Schleife über die CSV-Dateien
for csv_file in csv_files:
    # CSV-Datei laden
    df = pd.read_csv(csv_file)
    
    # Berechnungen
    mean_value = df["Average"].mean()
    median_value = df["Average"].median()
    num_records = df["Average"].count()
    
    # Ausgabe
    print(f"Datei: {csv_file}")
    print(f"Anzahl der Datensätze: {num_records}")
    print(f"Mittelwert (Mean) von 'Average': {mean_value}")
    print(f"Median von 'Average': {median_value}")
    print("----")
# Out:
# Datei: ./output/10min-sbj.csv
# Anzahl der Datensätze: 69
# Mittelwert (Mean) von 'Average': 179.34782608695653
# Median von 'Average': 184.0
# ----
# Datei: ./output/10min-srg.csv
# Anzahl der Datensätze: 71
# Mittelwert (Mean) von 'Average': 180.50704225352112
# Median von 'Average': 187.0
# ----
# Datei: ./output/10min-srj.csv
# Anzahl der Datensätze: 70
# Mittelwert (Mean) von 'Average': 181.47142857142856
# Median von 'Average': 186.0
# ----
# Datei: ./output/10min-sbvj.csv
# Anzahl der Datensätze: 67
# Mittelwert (Mean) von 'Average': 183.1044776119403
# Median von 'Average': 186.0
# ----
# Datei: ./output/10min-sbg.csv
# Anzahl der Datensätze: 72
# Mittelwert (Mean) von 'Average': 178.79166666666666
# Median von 'Average': 186.0
# ----

# %%
Spring Blocking JAR
Datei: ./output/10min-sbj.csv
Anzahl der Datensätze: 60
Mittelwert (Mean) von 'Average': 184.33333333333334
Median von 'Average': 184.0
----
Spring Non-Blocking JAR
Datei: ./output/10min-srj.csv
Anzahl der Datensätze: 60
Mittelwert (Mean) von 'Average': 187.21666666666667
Median von 'Average': 187.0
----
Spring Blocking Virtual Threads JAR
Datei: ./output/10min-sbvj.csv
Anzahl der Datensätze: 60
Mittelwert (Mean) von 'Average': 187.43333333333334
Median von 'Average': 186.5
----
Spring Blocking GRAAL
Datei: ./output/10min-sbg.csv
Anzahl der Datensätze: 60
Mittelwert (Mean) von 'Average': 185.26666666666668
Median von 'Average': 186.0
----
Spring Non-Blocking GRAAL
Datei: ./output/10min-srg.csv
Anzahl der Datensätze: 60
Mittelwert (Mean) von 'Average': 186.8
Median von 'Average': 188.0
# Out:
#   Cell In[9], line 1
#     Spring Blocking JAR
#            ^
# SyntaxError: invalid syntax
